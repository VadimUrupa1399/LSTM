# %%
from google.colab import files
iu = files.upload()
# Out:
#      <input type="file" id="files-420859f7-6357-4c5b-ba4c-cf5678b3db37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-420859f7-6357-4c5b-ba4c-cf5678b3db37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving household_power_consumption.txt to household_power_consumption.txt

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
df = pd.read_csv('household_power_consumption.txt', sep=';', 
                 parse_dates={'dt' : ['Date', 'Time']}, infer_datetime_format=True, 
                 low_memory=False, na_values=['nan','?'], index_col='dt')

df
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# dt
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
# ...                                  ...                    ...      ...
# 2010-11-26 20:58:00                0.946                  0.000   240.43
# 2010-11-26 20:59:00                0.944                  0.000   240.00
# 2010-11-26 21:00:00                0.938                  0.000   239.82
# 2010-11-26 21:01:00                0.934                  0.000   239.70
# 2010-11-26 21:02:00                0.932                  0.000   239.55
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# dt
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
# ...                               ...             ...             ...
# 2010-11-26 20:58:00               4.0             0.0             0.0
# 2010-11-26 20:59:00               4.0             0.0             0.0
# 2010-11-26 21:00:00               3.8             0.0             0.0
# 2010-11-26 21:01:00               3.8             0.0             0.0
# 2010-11-26 21:02:00               3.8             0.0             0.0
#
#                      Sub_metering_3
# dt
# 2006-12-16 17:24:00            17.0
# 2006-12-16 17:25:00            16.0
# 2006-12-16 17:26:00            17.0
# 2006-12-16 17:27:00            17.0
# 2006-12-16 17:28:00            17.0
# ...                             ...
# 2010-11-26 20:58:00             0.0
# 2010-11-26 20:59:00             0.0
# 2010-11-26 21:00:00             0.0
# 2010-11-26 21:01:00             0.0
# 2010-11-26 21:02:00             0.0
#
# [2075259 rows x 7 columns]

# %%
df.shape
# Out:
# (2075259, 7)

# %%
df.isna().sum()
# Out:
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# dtype: int64

# %%
df = df.fillna(df.mean())
df.isna().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %% [markdown]
# **have a look at the data more closely by visualizing it**

# %%
import matplotlib.pyplot as plt

i = 1
cols = [0, 1, 3, 4, 5, 6]
plt.figure(figsize=(20, 10))
for col in cols:
    plt.subplot(len(cols), 1, i)
    plt.plot(df.resample('M').mean().values[:, col])
    plt.title(df.columns[col] + ' data resample over month for mean', y=0.75, loc='left')
    i += 1
plt.show()

# %%
i = 1
cols=[0, 1, 3, 4, 5, 6]
plt.figure(figsize=(20, 10))
for col in cols:
    plt.subplot(len(cols), 1, i)
    plt.plot(df.resample('D').mean().values[:, col])
    plt.title(df.columns[col] + ' data resample over day for mean', y=0.75, loc='center')
    i += 1
plt.show()

# %%
i = 1
cols=[0, 1, 3, 4, 5, 6]
plt.figure(figsize=(20, 10))
for col in cols:
    plt.subplot(len(cols), 1, i)
    plt.plot(df.resample('H').mean().values[:, col])
    plt.title(df.columns[col] + ' data resample over hour for mean', y=0.75, loc='left')
    i += 1
plt.show()

# %% [markdown]
# # Observations from the above visualizations:
#
#
#
#
# *   Resampling by month, date or time is very important because it has a great interaction as expected (changing the periodicity of the system).
# *   Therefore, if you process all the original data, the run time will be very expensive, but if you process data with large timescale samples (e.g., monthly), it will affect the predictability of the model.
#
#
# *  From observation, we can see it is relatively reasonable to resample the data per hour.

# %% [markdown]
# # LSTM Model
# **For the task of energy consumption prediction with Machine Learning, I will use the LSTM model because it is very well suited for large time-series data. I’ll start this step by preparing a helper function to frame the problem**

# %%
df = df[['Global_active_power', 'Global_reactive_power', 'Voltage',
       'Global_intensity', 'Sub_metering_2', 'Sub_metering_1','Sub_metering_3']]
       
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    dff = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(dff.shift(-i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(dff.shift(-i))
        if i==0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1)) for j in range(n_vars)]        
        agg = pd.concat(cols, axis=1)
        agg.columns = names
        if dropnan:
            agg.dropna(inplace=True)
        return agg

# %% [markdown]
# **To reduce the time of the calculation and get the results fast, I will resample the dataset**

# %%
df_resample = df.resample('h').mean() 
df_resample.shape
# Out:
# (34589, 7)

# %%
df_resample.values
# Out:
# array([[4.22288889e+00, 2.29000000e-01, 2.34643889e+02, ...,
#         5.27777778e-01, 0.00000000e+00, 1.68611111e+01],
#        [3.63220000e+00, 8.00333333e-02, 2.34580167e+02, ...,
#         6.71666667e+00, 0.00000000e+00, 1.68666667e+01],
#        [3.40023333e+00, 8.52333333e-02, 2.33232500e+02, ...,
#         1.43333333e+00, 0.00000000e+00, 1.66833333e+01],
#        ...,
#        [1.65933333e+00, 6.00333333e-02, 2.36741000e+02, ...,
#         6.66666667e-02, 0.00000000e+00, 0.00000000e+00],
#        [1.16370000e+00, 6.11666667e-02, 2.39396000e+02, ...,
#         1.06666667e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.34666667e-01, 0.00000000e+00, 2.39690000e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
from sklearn.preprocessing import MinMaxScaler

values = df_resample.values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1)
r = list(range(df_resample.shape[1]+1, 2*df_resample.shape[1]))
reframed.drop(reframed.columns[r], axis=1, inplace=True)
reframed.head()

# Data spliting into train and test data series. Only 4000 first data points are selected for traing purpose.
values = reframed.values
n_train_time = 4000
train = values[:n_train_time, :]
test = values[n_train_time:, :]
train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]
train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
test_x = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))

# %% [markdown]
# # Now let’s use the LSTM model for the task of energy consumption prediction. Below are the parameters that I will use in the LSTM model
#
#
# *   100 neurons in the first visible layer
# *   dropout 10%
#
#
# *  1 neuron in the output layer to predict Global_active_power
#
# *  The entry form will be a step with 7 features
# *   The loss function mean_squared_error and Adam’s efficient version of stochastic gradient descent
#
#
# *  The model will be suitable for 50 training periods with a lot size of 70

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
import numpy as np

model = Sequential()
model.add(LSTM(100, input_shape=(train_x.shape[1], train_x.shape[2])))
model.add(Dropout(0.1))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Network fitting
history = model.fit(train_x, train_y, epochs=50, batch_size=70, validation_data=(test_x, test_y), verbose=2, shuffle=False)

# Loss history plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

size = df_resample.shape[1]

# Prediction test
yhat = model.predict(test_x)
test_x = test_x.reshape((test_x.shape[0], size))

# invert scaling for prediction
inv_yhat = np.concatenate((yhat, test_x[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_x[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)

aa=[x for x in range(500)]
plt.figure(figsize=(25,10)) 
plt.plot(aa, inv_y[:500], marker='.', label="actual")
plt.plot(aa, inv_yhat[:500], 'r', label="prediction")
plt.ylabel(df.columns[0], size=15)
plt.xlabel('Time step for first 500 hours', size=15)
plt.legend(fontsize=15)
plt.show()
# Out:
# Epoch 1/50
# 58/58 - 4s - loss: 0.0335 - val_loss: 0.0116 - 4s/epoch - 61ms/step
# Epoch 2/50
# 58/58 - 1s - loss: 0.0157 - val_loss: 0.0100 - 810ms/epoch - 14ms/step
# Epoch 3/50
# 58/58 - 1s - loss: 0.0142 - val_loss: 0.0098 - 811ms/epoch - 14ms/step
# Epoch 4/50
# 58/58 - 1s - loss: 0.0136 - val_loss: 0.0097 - 1s/epoch - 25ms/step
# Epoch 5/50
# 58/58 - 2s - loss: 0.0131 - val_loss: 0.0096 - 2s/epoch - 26ms/step
# Epoch 6/50
# 58/58 - 1s - loss: 0.0126 - val_loss: 0.0094 - 819ms/epoch - 14ms/step
# Epoch 7/50
# 58/58 - 1s - loss: 0.0123 - val_loss: 0.0093 - 823ms/epoch - 14ms/step
# Epoch 8/50
# 58/58 - 1s - loss: 0.0121 - val_loss: 0.0093 - 802ms/epoch - 14ms/step
# Epoch 9/50
# 58/58 - 1s - loss: 0.0120 - val_loss: 0.0092 - 803ms/epoch - 14ms/step
# Epoch 10/50
# 58/58 - 1s - loss: 0.0119 - val_loss: 0.0092 - 791ms/epoch - 14ms/step
# Epoch 11/50
# 58/58 - 1s - loss: 0.0119 - val_loss: 0.0092 - 801ms/epoch - 14ms/step
# Epoch 12/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0091 - 780ms/epoch - 13ms/step
# Epoch 13/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0091 - 808ms/epoch - 14ms/step
# Epoch 14/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 785ms/epoch - 14ms/step
# Epoch 15/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 790ms/epoch - 14ms/step
# Epoch 16/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0091 - 796ms/epoch - 14ms/step
# Epoch 17/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 773ms/epoch - 13ms/step
# Epoch 18/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 803ms/epoch - 14ms/step
# Epoch 19/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 774ms/epoch - 13ms/step
# Epoch 20/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 758ms/epoch - 13ms/step
# Epoch 21/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 799ms/epoch - 14ms/step
# Epoch 22/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0090 - 805ms/epoch - 14ms/step
# Epoch 23/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 809ms/epoch - 14ms/step
# Epoch 24/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 804ms/epoch - 14ms/step
# Epoch 25/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 768ms/epoch - 13ms/step
# Epoch 26/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0090 - 811ms/epoch - 14ms/step
# Epoch 27/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 789ms/epoch - 14ms/step
# Epoch 28/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 766ms/epoch - 13ms/step
# Epoch 29/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 797ms/epoch - 14ms/step
# Epoch 30/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 799ms/epoch - 14ms/step
# Epoch 31/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 815ms/epoch - 14ms/step
# Epoch 32/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 809ms/epoch - 14ms/step
# Epoch 33/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 801ms/epoch - 14ms/step
# Epoch 34/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 805ms/epoch - 14ms/step
# Epoch 35/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0090 - 785ms/epoch - 14ms/step
# Epoch 36/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 752ms/epoch - 13ms/step
# Epoch 37/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 815ms/epoch - 14ms/step
# Epoch 38/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0090 - 810ms/epoch - 14ms/step
# Epoch 39/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 808ms/epoch - 14ms/step
# Epoch 40/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 807ms/epoch - 14ms/step
# Epoch 41/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 810ms/epoch - 14ms/step
# Epoch 42/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 816ms/epoch - 14ms/step
# Epoch 43/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 808ms/epoch - 14ms/step
# Epoch 44/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 806ms/epoch - 14ms/step
# Epoch 45/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 799ms/epoch - 14ms/step
# Epoch 46/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 810ms/epoch - 14ms/step
# Epoch 47/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0090 - 773ms/epoch - 13ms/step
# Epoch 48/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 801ms/epoch - 14ms/step
# Epoch 49/50
# 58/58 - 1s - loss: 0.0114 - val_loss: 0.0090 - 800ms/epoch - 14ms/step
# Epoch 50/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 798ms/epoch - 14ms/step
# Test RMSE: 0.611
